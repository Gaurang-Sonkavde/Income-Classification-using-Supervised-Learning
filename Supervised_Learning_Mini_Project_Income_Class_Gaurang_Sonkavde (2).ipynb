# %% [markdown]
# Load Required Libraries

# %%
import numpy as np # mathematical calculation
import pandas as pd  # data preprocessing 
import matplotlib.pyplot as plt # data visualization
import seaborn as sns  # data visualization

# %% [markdown]
# Load Dataset

# %%
df = pd.read_csv("income_evaluation.csv")
df
# Out:
#        age          workclass   fnlwgt  ...  hours-per-week   native-country  income
# 0       39          State-gov    77516  ...              40    United-States   <=50K
# 1       50   Self-emp-not-inc    83311  ...              13    United-States   <=50K
# 2       38            Private   215646  ...              40    United-States   <=50K
# 3       53            Private   234721  ...              40    United-States   <=50K
# 4       28            Private   338409  ...              40             Cuba   <=50K
# ...    ...                ...      ...  ...             ...              ...     ...
# 32556   27            Private   257302  ...              38    United-States   <=50K
# 32557   40            Private   154374  ...              40    United-States    >50K
# 32558   58            Private   151910  ...              40    United-States   <=50K
# 32559   22            Private   201490  ...              20    United-States   <=50K
# 32560   52       Self-emp-inc   287927  ...              40    United-States    >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# Data Exploration and EDA

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 15

# %%
df[' workclass'].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age        fnlwgt  ...   capital-loss   hours-per-week
# count  32561.000000  3.256100e+04  ...   32561.000000     32561.000000
# mean      38.581647  1.897784e+05  ...      87.303830        40.437456
# std       13.640433  1.055500e+05  ...     402.960219        12.347429
# min       17.000000  1.228500e+04  ...       0.000000         1.000000
# 25%       28.000000  1.178270e+05  ...       0.000000        40.000000
# 50%       37.000000  1.783560e+05  ...       0.000000        40.000000
# 75%       48.000000  2.370510e+05  ...       0.000000        45.000000
# max       90.000000  1.484705e+06  ...    4356.000000        99.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Distribution Among Income Group

# %%
sns.countplot(x=' income',data=df )

# %%
income = df[' income'].value_counts()
print("Income of Citizens in USA in Price Bracket is given below : \n ",income)
# Out:
# Income of Citizens in USA in Price Bracket is given below :
#    <=50K    24720
#  >50K      7841
# Name:  income, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.title('Income by Range of $50K')
plt.pie(df[' income'].value_counts(), labels=income.values ,  shadow = True, autopct= '%1.1f%%')
plt.show()

# %%
print(f"<= 50k : {round(24720 /32561 * 100 , 2)}")
print(f"> 50k : {round(7841 /32561 * 100 , 2)}")
# Out:
# <= 50k : 75.92
# > 50k : 24.08

# %% [markdown]
# By All this Analysis we get to know that this is an unbalanced Dataset so we need to Balance it using Undersampling and Oversampling

# %% [markdown]
# Feature Engineering

# %% [markdown]
# Check Null Values

# %%
## Here we will check the missing values in our dataset
df.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %% [markdown]
# Check and Drop/Remove Duplicates

# %%
df.duplicated().sum()
# Out:
# 24

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        age          workclass   fnlwgt  ...  hours-per-week   native-country  income
# 0       39          State-gov    77516  ...              40    United-States   <=50K
# 1       50   Self-emp-not-inc    83311  ...              13    United-States   <=50K
# 2       38            Private   215646  ...              40    United-States   <=50K
# 3       53            Private   234721  ...              40    United-States   <=50K
# 4       28            Private   338409  ...              40             Cuba   <=50K
# ...    ...                ...      ...  ...             ...              ...     ...
# 32556   27            Private   257302  ...              38    United-States   <=50K
# 32557   40            Private   154374  ...              40    United-States    >50K
# 32558   58            Private   151910  ...              40    United-States   <=50K
# 32559   22            Private   201490  ...              20    United-States   <=50K
# 32560   52       Self-emp-inc   287927  ...              40    United-States    >50K
#
# [32537 rows x 15 columns]

# %% [markdown]
# Handling Numerical features

# %%
numerical_features = [i for i in df.columns if df[i].dtypes != "O"]

# %%
numerical_features
# Out:
# ['age',
#  ' fnlwgt',
#  ' education-num',
#  ' capital-gain',
#  ' capital-loss',
#  ' hours-per-week']

# %%
for i in numerical_features:
    print(f" {i}  :  {len(df[i].unique())}")
# Out:
#  age  :  73
#   fnlwgt  :  21648
#   education-num  :  16
#   capital-gain  :  119
#   capital-loss  :  92
#   hours-per-week  :  94

# %% [markdown]
# #### As we can see that education-num has less no of values so this is not Continuous

# %%
df[" education-num"].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8])

# %% [markdown]
# Handling categorical data

# %%
categorical = [i for i in df.columns if df[i].dtypes == "O"]

# %%
for feature in categorical:
    print(f" {feature}  :  {len(df[feature].unique())}")
# Out:
#   workclass  :  9
#   education  :  16
#   marital-status  :  7
#   occupation  :  15
#   relationship  :  6
#   race  :  5
#   sex  :  2
#   native-country  :  42
#   income  :  2

# %%
for feature in  categorical:
    print(df[feature].value_counts()) 
    print("\n \n ")
# Out:
#  Private             22673
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  workclass, dtype: int64
#
#
#
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5353
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# Name:  education, dtype: int64
#
#
#
#  Married-civ-spouse       14970
#  Never-married            10667
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name:  marital-status, dtype: int64
#
#
#
#  Prof-specialty       4136
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3768
#  Sales                3650
#  Other-service        3291
#  Machine-op-inspct    2000
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# Name:  occupation, dtype: int64
#
#
#
#  Husband           13187
#  Not-in-family      8292
#  Own-child          5064
#  Unmarried          3445
#  Wife               1568
#  Other-relative      981
# Name:  relationship, dtype: int64
#
#
#
#  White                 27795
#  Black                  3122
#  Asian-Pac-Islander     1038
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name:  race, dtype: int64
#
#
#
#  Male      21775
#  Female    10762
# Name:  sex, dtype: int64
#
#
#
#  United-States                 29153
#  Mexico                          639
#  ?                               582
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        62
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Trinadad&Tobago                  19
#  Cambodia                         19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# Name:  native-country, dtype: int64
#
#
#
#  <=50K    24698
#  >50K      7839
# Name:  income, dtype: int64

# %% [markdown]
# Handling missing values in categorical features

# %%
print(f"workclass : {round(2093 / 32561 , 4) *100}%")
print(f"occupation : {round(1843 / 32561 , 4) *100}%")
print(f"native-country : {round(583 / 32561 , 4) *100}%")
# Out:
# workclass : 6.43%
# occupation : 5.66%
# native-country : 1.79%

# %%
df[" occupation"].mode()[0]
# Out:
# ' Prof-specialty'

# %%
df[' native-country'].mode()[0]
# Out:
# ' United-States'

# %%
df[' workclass'].mode()[0]
# Out:
# ' Private'

# %% [markdown]
# **here we have less than 6 percent missing values so we can fill it with mode value**

# %%
df[" workclass"] = df[' workclass'].str.replace('?', 'Private' )
df[' occupation'] = df[' occupation'].str.replace('?', 'Prof-specialty' )
df[' native-country'] = df[' native-country'].str.replace('?', 'United-States' )

# %% [markdown]
# #### Club educational categories

# %%
# education Category
df[" education"].replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'school' ,inplace = True , regex = True)
df[" education"].replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'higher' , inplace = True , regex = True)

# %% [markdown]
# #### Club Maritial Status

# %%
#martial status
df[' marital-status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married' , inplace = True , regex = True)
df[' marital-status'].replace(['Divorced', 'Separated','Widowed','Married-spouse-absent'], 'other' , inplace = True , regex = True)

# %% [markdown]
# #### For Binary classification keep output as 0 and 1 for more than and less than
# #### $50K income

# %%
# income
df[' income'] = df[' income'].replace({'<=50K' : 0 , ">50K" : 1 } , regex = True)

# %%
df
# Out:
#             age          workclass  ...   native-country  income
# 0      3.663562          State-gov  ...    United-States       0
# 1      3.912023   Self-emp-not-inc  ...    United-States       0
# 2      3.637586            Private  ...    United-States       0
# 3      3.970292            Private  ...    United-States       0
# 4      3.332205            Private  ...             Cuba       0
# ...         ...                ...  ...              ...     ...
# 32556  3.295837            Private  ...    United-States       0
# 32557  3.688879            Private  ...    United-States       1
# 32558  4.060443            Private  ...    United-States       0
# 32559  3.091042            Private  ...    United-States       0
# 32560  3.951244       Self-emp-inc  ...    United-States       1
#
# [32537 rows x 15 columns]

# %%
for feature in categorical:
    print(f" {feature}  :  {len(df[feature].unique())}")
# Out:
#   workclass  :  8
#   education  :  6
#   marital-status  :  3
#   occupation  :  14
#   relationship  :  6
#   race  :  5
#   sex  :  2
#   native-country  :  41
#   income  :  2

# %%
Education = df[' education'].value_counts()
print("No of Education Level in USA is given below : \n ",Education)
# Out:
# No of Education Level in USA is given below :
#    HS-grad      10494
#  higher       10307
#  Bachelors     5353
#  school        4248
#  Masters       1722
#  Doctorate      413
# Name:  education, dtype: int64

# %%
print(f"HS-grad : {round(10501 /32561 * 100 , 6)}")
print(f"higher : {round(10316 /32561 * 100 , 6)}")
print(f"Bachelors : {round(5355 /32561 * 100 , 6)}")
print(f"school : {round(4253 /32561 * 100 , 6)}")
print(f"Masters : {round(1723 /32561 * 100 , 6)}")
print(f"Doctorate : {round(413 /32561 * 100 , 6)}")
# Out:
# HS-grad : 32.250238
# higher : 31.682074
# Bachelors : 16.446055
# school : 13.061638
# Masters : 5.291607
# Doctorate : 1.268389

# %%
plt.figure(figsize=(6,6))
plt.title('Piechart of Education Level in USA is given below')
plt.pie(df[' education'].value_counts(), labels=Education.values ,  shadow = True, autopct= '%1.1f%%')
plt.show()

# %%
df[" education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' school', ' Masters', ' higher',
#        ' Doctorate'], dtype=object)

# %% [markdown]
# ## Find Correlations

# %%
sns.pairplot(df)

# %%
plt.figure(figsize = (16 , 7))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ### Label Encoded Data

# %%
from sklearn.preprocessing import  LabelEncoder

# %%
df = df.apply(LabelEncoder().fit_transform)
df
# Out:
#        age   workclass   fnlwgt  ...   hours-per-week   native-country   income
# 0       22           6     2671  ...               39               38        0
# 1       33           5     2926  ...               12               38        0
# 2       21           3    14086  ...               39               38        0
# 3       36           3    15336  ...               39               38        0
# 4       11           3    19355  ...               39                4        0
# ...    ...         ...      ...  ...              ...              ...      ...
# 32556   10           3    16528  ...               37               38        0
# 32557   23           3     8080  ...               39               38        1
# 32558   41           3     7883  ...               39               38        0
# 32559    5           3    12881  ...               19               38        0
# 32560   35           4    17825  ...               39               38        1
#
# [32537 rows x 15 columns]

# %% [markdown]
# ### Outlier Detection for Income and Age

# %% [markdown]
# #### Here we can see that there are some outliers so we need to remove them we can do that by Using Inter Quartile Range

# %%
sns.boxplot(x = ' income', y = 'age', data = df)

# %%
def outlierdetection(df):
    sorted(df)
    
    Q1,Q3=np.percentile(df,[25,75])
    
    IQR=Q3-Q1
    
    lower_range=Q1-(1.5*IQR)
    
    Upper_range=Q3+(1.5*IQR)
    
    return lower_range,Upper_range

# %%
a1 = df[(df[' income'] == 0 )].age
Lr,Ur=outlierdetection(a1)
print("Lower Range : ",Lr)
print("Upper Range : ",Ur)
# Out:
# Lower Range :  -23.5
# Upper Range :  60.5

# %%
a2 = df[(df[' income'] == 1 )].age
Lr,Ur=outlierdetection(a2)
print("Lower Range : ",Lr)
print("Upper Range : ",Ur)
# Out:
# Lower Range :  -3.5
# Upper Range :  56.5

# %%
df.drop(df.index[(df[' income'] == 0) & (df['age'] < Lr)],inplace=True)
df.drop(df.index[(df[' income'] == 0) & (df['age'] > Ur)],inplace=True)

# %%
df.drop(df.index[(df[' income'] == 1) & (df['age'] < Lr)],inplace=True)
df.drop(df.index[(df[' income'] == 1) & (df['age'] > Ur)],inplace=True)

# %%
sns.boxplot(x = ' income', y = 'age', data = df)

# %% [markdown]
# Outlier removed of Income and Age

# %% [markdown]
# Later we also have good Co-relation for Income and education-num so lets find Outlier for it

# %%
sns.boxplot(x = ' income', y = ' education-num', data = df)

# %%
b1 = df[(df[' income'] == 0 )][" education-num"]
Lr,Ur=outlierdetection(b1)
print("Lower Range : ",Lr)
print("Upper Range : ",Ur)
# Out:
# Lower Range :  6.5
# Upper Range :  10.5

# %%
b2 = df[(df[' income'] == 1 )][" education-num"]
Lr,Ur=outlierdetection(b2)
print("Lower Range : ",Lr)
print("Upper Range : ",Ur)
# Out:
# Lower Range :  4.5
# Upper Range :  16.5

# %%
df.drop(df.index[(df[' income'] == 0) & (df[' education-num'] < Lr)],inplace=True)
df.drop(df.index[(df[' income'] == 0) & (df[' education-num'] > Ur)],inplace=True)

# %%
df.drop(df.index[(df[' income'] == 1) & (df[' education-num'] < Lr)],inplace=True)
df.drop(df.index[(df[' income'] == 1) & (df[' education-num'] > Ur)],inplace=True)

# %%
sns.boxplot(x = ' income', y = ' education-num', data = df)

# %% [markdown]
# Here we can see I have succesfully removed Outlier for Income and education-num

# %%
sns.countplot(x=' income',data=df )

# %% [markdown]
# Value Counts of Class 0 and Class 1

# %%
count_class_0,count_class_1 = df[' income'].value_counts()
df_class_0 = df[df[' income']==0]
df_class_1 = df[df[' income']==1]

# %%
df_class_0.shape
# Out:
# (22865, 15)

# %%
df_class_1.shape
# Out:
# (7692, 15)

# %% [markdown]
# ## Oversampling

# %%
df_class_1_over = df_class_1.sample(count_class_0,replace=True)
df_test_over = pd.concat([df_class_0,df_class_1_over],axis = 0)
print("Random Over-Sampling")
print(df_test_over[' income'].value_counts())
# Out:
# Random Over-Sampling
# 1    22865
# 0    22865
# Name:  income, dtype: int64

# %%
sns.countplot(x=' income',data=df_test_over )

# %%
X = df_test_over.drop(columns=[' income'])
y = df_test_over[' income']

# %%
X
# Out:
#        age   workclass  ...   hours-per-week   native-country
# 0       22           6  ...               39               38
# 1       33           5  ...               12               38
# 2       21           3  ...               39               38
# 3       36           3  ...               39               38
# 4       11           3  ...               39                4
# ...    ...         ...  ...              ...              ...
# 22506   20           3  ...               44               38
# 19950   24           0  ...               43               38
# 17136   33           3  ...               68               38
# 18923   31           3  ...               59               38
# 6758    30           5  ...               39               38
#
# [45730 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=123,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# ### Check which Algorithms Fits Best Among all the Algorithms based on Accuracy for Oversampled Data

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %%
names = [ "K-Nearest Neighbors", "Linear SVM", "Gradient_Boosting", "Decision Tree", "Random Forest", "AdaBoost", "Naive Bayes", "Logistic_Regression" ]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    GradientBoostingClassifier(n_estimators=100,learning_rate=1.0),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    AdaBoostClassifier(n_estimators=100),
    GaussianNB(),
    LogisticRegression()
]

# %%
scores = []
for name, clf in zip(names,classifiers):
  clf.fit(X_train,y_train)
  score = clf.score(X_test,y_test)
  scores.append(score)

# %%
scores
# Out:
# [0.8572053356658649,
#  0.7650338945987317,
#  0.8357752022742182,
#  0.812923682484146,
#  0.7968510824404111,
#  0.8199212770610103,
#  0.741198338071288,
#  0.7613164224797726]

# %%
df2 = pd.DataFrame()
df2['Names'] = names
df2['Score'] = scores
df2
# Out:
#                  Names     Score
# 0  K-Nearest Neighbors  0.857205
# 1           Linear SVM  0.765034
# 2    Gradient_Boosting  0.835775
# 3        Decision Tree  0.812924
# 4        Random Forest  0.796851
# 5             AdaBoost  0.819921
# 6          Naive Bayes  0.741198
# 7  Logistic_Regression  0.761316

# %%
cm = sns.light_palette('blue',as_cmap=True)
s = df2.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row0_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row1_col1{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row2_col1{
#             background-color:  #2c2cfd;
#             color:  #f1f1f1;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row3_col1{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row4_col1{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row5_col1{
#             background-color:  #4d4dfb;
#             color:  #f1f1f1;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row6_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row7_col1{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }</style><table id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Names</th>        <th class="col_heading level0 col1" >Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row0_col0" class="data row0 col0" >K-Nearest Neighbors</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row0_col1" class="data row0 col1" >0.857205</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row1_col0" class="data row1 col0" >Linear SVM</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row1_col1" class="data row1 col1" >0.765034</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row2_col0" class="data row2 col0" >Gradient_Boosting</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row2_col1" class="data row2 col1" >0.835775</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row3_col0" class="data row3 col0" >Decision Tree</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row3_col1" class="data row3 col1" >0.812924</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row4_col0" class="data row4 col0" >Random Forest</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row4_col1" class="data row4 col1" >0.796851</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row5_col0" class="data row5 col0" >AdaBoost</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row5_col1" class="data row5 col1" >0.819921</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row6_col0" class="data row6 col0" >Naive Bayes</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row6_col1" class="data row6 col1" >0.741198</td>
#             </tr>
#             <tr>
#                         <th id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row7_col0" class="data row7 col0" >Logistic_Regression</td>
#                         <td id="T_d2fcd6a0_6c6d_11ec_85c6_0242ac1c0002row7_col1" class="data row7 col1" >0.761316</td>
#             </tr>
#     </tbody></table>

# %%
sns.set(style="whitegrid")
ax = sns.barplot(y ='Names',x = 'Score',data = df2)

# %% [markdown]
# ### We can see that for Oversampled Data K Nearest Neaghbour Performs Best among all Algorithm so lets Implement it

# %%
classifier = KNeighborsClassifier(n_neighbors=5,weights='uniform',algorithm='auto',metric = 'minkowski')

# %%
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,roc_curve,auc

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.82      4573
#            1       0.80      0.90      0.85      4573
#
#     accuracy                           0.84      9146
#    macro avg       0.84      0.84      0.83      9146
# weighted avg       0.84      0.84      0.83      9146

# %%
c_m = confusion_matrix(y_test, y_pred )
plt.title('Heatmap of Confusion Matrix', fontsize = 12)
sns.heatmap(c_m, annot = True ,  fmt =   "d")
plt.show()

# %%
roc_auc_score(y_test,y_pred)
# Out:
# 0.8354471900284277

# %%
fpr,tpr,threshold =roc_curve(y_test,y_pred)
auc = auc(fpr,tpr)

# %%
# Receiver operator Characteristics(ROC)
plt.figure(figsize=(5,5),dpi=100)
plt.plot(fpr,tpr,linestyle='-',label = "(auc = %0.3f)" % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# ## Undersampling

# %%
df_class_0_under = df_class_0.sample(count_class_1)
df_test_under = pd.concat([df_class_0_under,df_class_1],axis=0)
df_test_under.shape
# Out:
# (15384, 15)

# %%
print('Random under-sampling')
print(df_test_under[' income'].value_counts())
# Out:
# Random under-sampling
# 1    7692
# 0    7692
# Name:  income, dtype: int64

# %%
X1 = df_test_under.drop(columns=[' income'])
y1 = df_test_under[' income']

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1,test_size = 0.2,random_state=123,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X1_train = scaler.fit_transform(X1_train)
X1_test = scaler.fit_transform(X1_test)

# %%
names = [
    "Nearest Neighbors",
    "Linear SVM",
    "Gradient_Boosting",
    "Decision Tree",
    "Random Forest",
    "AdaBoost",
    "Naive Bayes",
    "Logistic_Regression",
]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    GradientBoostingClassifier(n_estimators=100,learning_rate=1.0),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    AdaBoostClassifier(n_estimators=100),
    GaussianNB(),
    LogisticRegression()
]

# %%
scores = []
for name, clf in zip(names,classifiers):
  clf.fit(X1_train,y1_train)
  score = clf.score(X1_test,y1_test)
  scores.append(score)

# %%
df2 = pd.DataFrame()
df2['Names'] = names
df2['Score'] = scores
df2
# Out:
#                  Names     Score
# 0    Nearest Neighbors  0.790179
# 1           Linear SVM  0.768176
# 2    Gradient_Boosting  0.786033
# 3        Decision Tree  0.815051
# 4        Random Forest  0.800702
# 5             AdaBoost  0.808992
# 6          Naive Bayes  0.747449
# 7  Logistic_Regression  0.767538

# %%
cm = sns.light_palette('green',as_cmap=True)
s = df2.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
# #T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row0_col1{
#             background-color:  #56aa56;
#             color:  #000000;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row1_col1{
#             background-color:  #a3d0a3;
#             color:  #000000;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row2_col1{
#             background-color:  #64b164;
#             color:  #000000;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row3_col1{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row4_col1{
#             background-color:  #329832;
#             color:  #000000;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row5_col1{
#             background-color:  #148a14;
#             color:  #000000;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row6_col1{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row7_col1{
#             background-color:  #a5d1a5;
#             color:  #000000;
#         }</style><table id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Names</th>        <th class="col_heading level0 col1" >Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row0_col0" class="data row0 col0" >Nearest Neighbors</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row0_col1" class="data row0 col1" >0.790179</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row1_col0" class="data row1 col0" >Linear SVM</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row1_col1" class="data row1 col1" >0.768176</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row2_col0" class="data row2 col0" >Gradient_Boosting</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row2_col1" class="data row2 col1" >0.786033</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row3_col0" class="data row3 col0" >Decision Tree</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row3_col1" class="data row3 col1" >0.815051</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row4_col0" class="data row4 col0" >Random Forest</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row4_col1" class="data row4 col1" >0.800702</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row5_col0" class="data row5 col0" >AdaBoost</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row5_col1" class="data row5 col1" >0.808992</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row6_col0" class="data row6 col0" >Naive Bayes</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row6_col1" class="data row6 col1" >0.747449</td>
#             </tr>
#             <tr>
#                         <th id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row7_col0" class="data row7 col0" >Logistic_Regression</td>
#                         <td id="T_6d8b9c2a_681c_11ec_b54c_0242ac1c0002row7_col1" class="data row7 col1" >0.767538</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# For Undersampling Data Best Accuracy which we get is in Decision Tree Algorithm so lets Implement it

# %% [markdown]
# ## Decision Tree

# %%
classifier2 = DecisionTreeClassifier(criterion='entropy',max_depth=3)
classifier2.fit(X1_train, y1_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_pred1 = classifier2.predict(X1_test)

# %%
print(classification_report(y1_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.67      0.75      1568
#            1       0.73      0.90      0.81      1568
#
#     accuracy                           0.78      3136
#    macro avg       0.80      0.78      0.78      3136
# weighted avg       0.80      0.78      0.78      3136

# %%
import graphviz
from sklearn.tree import DecisionTreeClassifier,export_graphviz
from IPython.display import Image  
import pydotplus
from io import StringIO
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor as regr

# %%
dot_data = StringIO()

# %%
tree.export_graphviz(classifier, out_file = dot_data, filled = True, feature_names=['age', ' workclass', ' fnlwgt', ' education', ' education-num',
       ' marital-status', ' occupation', ' relationship', ' race', ' sex',
       ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country'], rounded = True, special_characters = True, impurity = False)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

# %%
graph.write_png("Income.png")
# Out:
# True

# %%
image = plt.imread('Income.png')
plt.figure(figsize=(15,15))
plt.imshow(image)

# %% [markdown]
# Coclusion :
#
# Here we can rightly classify the income group of American Citizens
#
# This Dataset was Unbanced dataset so I have checked using Oversampling and Undersampling
#
# In Oversampling K-Nearest Neighbour Model works best
#
# In undersampling Decison Tree works Best
